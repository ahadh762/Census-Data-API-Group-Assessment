# %% [markdown]
# * [GET AN API KEY](https://api.census.gov/data/key_signup.html)<br/><br/>
#
# * [North American Industry Classification System (NAICS) Codes](https://www.census.gov/naics/?58967?yearbck=2017) <br/><br/>
# * [Variable Names Documentation](https://www2.census.gov/programs-surveys/abs/technical-documentation/api/API2020-company-summary-10-4-2021.pdf)

# %%
# US CENSUS DATA
import pandas as pd

# MAKE SURE THERE ARE NO WHITE SPACES IN ANY VARIABLE
labels = 'NAME,GEO_ID,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,RACE_GROUP,VET_GROUP,FIRMPDEMP'

data_group = '&for=us'  # FOR ENTIRE USA
# data_group = '&for=metropolitan%20statistical%20area/micropolitan%20statistical%20' # FOR METROPOLITAN AREAS
#data_group = '&for=state' # FOR STATES

# Set area = '' for USA and US STATES
# area = 'area:12060'
area = ''

# YOU CAN GET MULTIPLE VALUES by doing &NAICS2017=00&NAICS2017=11
NAICS2017_value = '&NAICS2017=11'

API_key = '&key=1ba63b3df04e1bd07755febe18f836df1b86fc9f'

df = pd.read_json(f'https://api.census.gov/data/2018/abscs?get={labels}{data_group}{area}{NAICS2017_value}{API_key}')
df
# Out:
#                 0          1                                           2   \
# 0             NAME     GEO_ID                             NAICS2017_LABEL
# 1    United States  0100000US  Agriculture, forestry, fishing and hunting
# 2    United States  0100000US  Agriculture, forestry, fishing and hunting
# 3    United States  0100000US  Agriculture, forestry, fishing and hunting
# 4    United States  0100000US  Agriculture, forestry, fishing and hunting
# ..             ...        ...                                         ...
# 152  United States  0100000US  Agriculture, forestry, fishing and hunting
# 153  United States  0100000US  Agriculture, forestry, fishing and hunting
# 154  United States  0100000US  Agriculture, forestry, fishing and hunting
# 155  United States  0100000US  Agriculture, forestry, fishing and hunting
# 156  United States  0100000US  Agriculture, forestry, fishing and hunting
#
#       3                    4          5           6          7          8   \
# 0    SEX            SEX_LABEL  ETH_GROUP  RACE_GROUP  VET_GROUP  FIRMPDEMP
# 1    001                Total        001          00        001      26074
# 2    002               Female        001          00        001       3053
# 3    003                 Male        001          00        001      16313
# 4    004  Equally male/female        001          00        001       5605
# ..   ...                  ...        ...         ...        ...        ...
# 152  001                Total        029          60        001          0
# 153  002               Female        029          60        001          2
# 154  003                 Male        029          60        001          0
# 155  004  Equally male/female        029          60        001          0
# 156  001                Total        001          70        001         21
#
#             9   10
# 0    NAICS2017  us
# 1           11   1
# 2           11   1
# 3           11   1
# 4           11   1
# ..         ...  ..
# 152         11   1
# 153         11   1
# 154         11   1
# 155         11   1
# 156         11   1
#
# [157 rows x 11 columns]

# %%
# WITH DESCRIPTION LABELS

# MAKE SURE THERE ARE NO WHITE SPACES IN ANY VARIABLE STRINGS
labels = 'NAME,GEO_ID,NAICS2017_LABEL,SEX,ETH_GROUP,RACE_GROUP,VET_GROUP,FIRMPDEMP,QDESC,QDESC_LABEL'

data_group = '&for=us'  # FOR ENTIRE USA
#data_group = '&for=state' # FOR STATES


description =f'&{data_group}*&QDESC_LABEL=SPOUSES'
API_key = '&key=1ba63b3df04e1bd07755febe18f836df1b86fc9f'

df = pd.read_json(f'https://api.census.gov/data/2018/abscb?get={labels}{data_group}{description}{API_key}')
df.head()
# Out:
#               0          1                      2    3          4   \
# 0           NAME     GEO_ID        NAICS2017_LABEL  SEX  ETH_GROUP
# 1  United States  0100000US  Total for all sectors  001        001
# 2  United States  0100000US  Total for all sectors  003        001
# 3  United States  0100000US  Total for all sectors  002        001
# 4  United States  0100000US  Total for all sectors  002        028
#
#            5          6          7      8            9            10  11
# 0  RACE_GROUP  VET_GROUP  FIRMPDEMP  QDESC  QDESC_LABEL  QDESC_LABEL  us
# 1          00        001    5722142    B03      SPOUSES      SPOUSES   1
# 2          00        001    3496959    B03      SPOUSES      SPOUSES   1
# 3          00        001    1141410    B03      SPOUSES      SPOUSES   1
# 4          00        001       2220    B03      SPOUSES      SPOUSES   1
